# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from Generators.session_generator import generate_sessions
from Generators.User_Generator import get_user

# %%
sessions = generate_sessions('U1001')

# %%
sessions
# Out:
# [{'timestamp': '2026-03-16T11:48:50.683566',
#   'user_id': 'U1001',
#   'session_id': 'S128120',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': None,
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'chrome',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/home',
#   'referrer_url': None,
#   'time_on_page': 10.786059752689738,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T11:49:18.683566',
#   'user_id': 'U1001',
#   'session_id': 'S128120',
#   'event_id': 'E00001',
#   'page': 'deals',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': None,
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'chrome',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/deals',
#   'referrer_url': '/home',
#   'time_on_page': 40.883340360531626,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T11:49:28.683566',
#   'user_id': 'U1001',
#   'session_id': 'S128120',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': None,
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'chrome',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/home',
#   'referrer_url': '/deals',
#   'time_on_page': 38.53310141444209,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T11:49:40.683566',
#   'user_id': 'U1001',
#   'session_id': 'S128120',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'H5007',
#   'category': 'home',
#   'price': 19199,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'chrome',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/product/H5007',
#   'referrer_url': '/home',
#   'time_on_page': 24.651702232710022,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T11:50:02.683566',
#   'user_id': 'U1001',
#   'session_id': 'S128120',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'H5015',
#   'category': 'home',
#   'price': 3999,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'chrome',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/product/H5015',
#   'referrer_url': '/product/H5007',
#   'time_on_page': 17.876334694635197,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T11:50:37.683566',
#   'user_id': 'U1001',
#   'session_id': 'S128120',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'home',
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'chrome',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/home',
#   'referrer_url': '/product/H5015',
#   'time_on_page': 35.44619878545006,
#   'cart_value': None,
#   'is_purchase': False}]

# %%
len(sessions)
# Out:
# 6

# %%
import pandas as pd

# %%
df = pd.DataFrame(sessions)

# %%
df
# Out:
#                     timestamp user_id session_id event_id     page  \
# 0  2026-03-16T11:48:50.683566   U1001    S128120   E00001     home
# 1  2026-03-16T11:49:18.683566   U1001    S128120   E00001    deals
# 2  2026-03-16T11:49:28.683566   U1001    S128120   E00001     home
# 3  2026-03-16T11:49:40.683566   U1001    S128120   E00005  product
# 4  2026-03-16T11:50:02.683566   U1001    S128120   E00005  product
# 5  2026-03-16T11:50:37.683566   U1001    S128120   E00001     home
#
#      event_type product_id category    price quantity device_type browser  \
# 0     page_view        NaN      NaN      NaN     None      tablet  chrome
# 1     page_view        NaN      NaN      NaN     None      tablet  chrome
# 2     page_view        NaN      NaN      NaN     None      tablet  chrome
# 3  view_product      H5007     home  19199.0     None      tablet  chrome
# 4  view_product      H5015     home   3999.0     None      tablet  chrome
# 5     page_view        NaN     home      NaN     None      tablet  chrome
#
#   country traffic_source        page_url    referrer_url  time_on_page  \
# 0   India         social           /home             NaN     10.786060
# 1   India         social          /deals           /home     40.883340
# 2   India         social           /home          /deals     38.533101
# 3   India         social  /product/H5007           /home     24.651702
# 4   India         social  /product/H5015  /product/H5007     17.876335
# 5   India         social           /home  /product/H5015     35.446199
#
#   cart_value  is_purchase
# 0       None        False
# 1       None        False
# 2       None        False
# 3       None        False
# 4       None        False
# 5       None        False

# %%
sessions = generate_sessions('U1002')

# %%
sessions
# Out:
# [{'timestamp': '2026-03-16T04:36:31.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': None,
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/home',
#   'referrer_url': None,
#   'time_on_page': 16.080069684485398,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:36:55.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00003',
#   'page': 'category',
#   'event_type': 'browse_category',
#   'product_id': None,
#   'category': 'books',
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/category/books',
#   'referrer_url': '/home',
#   'time_on_page': 9.08384276424459,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:37:39.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'books',
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/home',
#   'referrer_url': '/category/books',
#   'time_on_page': 55.84415696477604,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:37:51.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'B3023',
#   'category': 'books',
#   'price': 1099,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/product/B3023',
#   'referrer_url': '/home',
#   'time_on_page': 58.57926650541794,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:38:07.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00009',
#   'page': 'wishlist',
#   'event_type': 'add_to_wishlist',
#   'product_id': None,
#   'category': 'books',
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/wishlist',
#   'referrer_url': '/product/B3023',
#   'time_on_page': 8.726115897436035,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:38:48.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'books',
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/home',
#   'referrer_url': '/wishlist',
#   'time_on_page': 50.32492079965746,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:39:21.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00001',
#   'page': 'deals',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'books',
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/deals',
#   'referrer_url': '/home',
#   'time_on_page': 24.335379111770187,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-16T04:39:48.862488',
#   'user_id': 'U1002',
#   'session_id': 'S320190',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'books',
#   'price': None,
#   'quantity': None,
#   'device_type': 'mobile',
#   'browser': 'Brave_mobile',
#   'country': 'Russia',
#   'traffic_source': 'organic',
#   'page_url': '/home',
#   'referrer_url': '/deals',
#   'time_on_page': 7.393164068680103,
#   'cart_value': None,
#   'is_purchase': False}]

# %%
df = pd.DataFrame(sessions)

# %%
df.columns
# Out:
# Index(['timestamp', 'user_id', 'session_id', 'event_id', 'page', 'event_type',
#        'product_id', 'category', 'price', 'quantity', 'device_type', 'browser',
#        'country', 'traffic_source', 'page_url', 'referrer_url', 'time_on_page',
#        'cart_value', 'is_purchase'],
#       dtype='str')

# %%
dict1 = {
    "Name":"Asim"
}

# %%
dict1['Name']
# Out:
# 'Asim'

# %%
dict1.get("Name")
# Out:
# 'Asim'

# %%
from Generators.User_Generator import user_profiles,get_user

# %%
user_profiles['user_00001']['total_orders']+=1

# %%
user_profiles
# Out:
# {'user_00001': {'user_id': 'user_00001',
#   'age': 56,
#   'gender': 'female',
#   'country': 'India',
#   'signup_date': datetime.datetime(2026, 1, 4, 10, 40, 35, 295275),
#   'membership_type': 'normal',
#   'total_orders': 1}}

# %%
user_id = get_user()

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(user_profiles,orient='index')

# %%
df
# Out:
#                user_id  age  gender country                signup_date  \
# user_00001  user_00001   56  female   India 2026-01-04 10:40:35.295275
#
#            membership_type  total_orders
# user_00001          normal             0

# %%
import random

products = {
    "electronics": [f"E{i}" for i in range(1000,1030)],
    "fashion": [f"F{i}" for i in range(2000,2030)],
    "books": [f"B{i}" for i in range(3000,3030)],
    "sports": [f"S{i}" for i in range(4000,4030)],
    "home": [f"H{i}" for i in range(5000,5030)]
}
BRANDS = {
    "electronics": ["Samsung","Apple","OnePlus","Xiaomi","boAt","Sony","LG","Realme","Lenovo","Noise"],
    "fashion": ["Fabindia","W for Woman","Manyavar","Peter England","Van Heusen","Biba","Raymond","Allen Solly","Aurelia","Jockey"],
    "books": ["Penguin India","Rupa Publications","Westland Books","Harper Collins India","Fingerprint Publishing","Notion Press","Jaico Publishing","Oxford India","Bloomsbury India","Scholastic India"],
    "sports": ["Nivia","Cosco","Vector X","SS Cricket","SG Cricket","Yonex","Adidas India","Nike India","Decathlon","OMTEX"],
    "home": ["Prestige","Bajaj Electricals","Havells","Milton","Cello","Godrej","Nilkamal","Asian Paints","Philips India","Pigeon"]
}
price_ranges = { 
    "electronics": (5000, 80000), 
    "fashion": (300, 5000), 
    "books": (150, 1200), 
    "sports": (500, 15000), 
    "home": (800, 25000) 
}
product_price = {}
for category,product_list in products.items():
    low, high = price_ranges[category]
    for product_id in product_list:
        price = random.randint(low,high)
        price = int(round(price/100)) * 100 - 1
        product_price[product_id] = price
DISCOUNT_RANGES = {
    "electronics": (5, 35),   
    "fashion":     (10, 80),  
    "books":       (10, 40),   
    "sports":      (10, 50),   
    "home":        (5, 60),    
}
def generate_discount(category: str) -> int:
    low, high = DISCOUNT_RANGES[category]
    return random.randint(low, high)


products_details = []
for category in products.keys():
    for product_id in products[category]:
        data = {
            'product_id':product_id,
            'category':category,
            'brand':random.choice(BRANDS[category]),
            'price':product_price.get(product_id),
            'rating':round(random.uniform(2.5, 5.0), 1),
            'stock':random.randint(1000,10000),
            'discount':str(round(generate_discount(category),2))+'%'
        }
        products_details.append(data)

# %%
len(products_details)
# Out:
# 150

# %%
df = pd.DataFrame(products_details)
df
# Out:
#     product_id     category              brand  price  rating  stock discount
# 0        E1000  electronics              Noise  31899     3.4   9759      34%
# 1        E1001  electronics             Realme   5699     2.8   4318      16%
# 2        E1002  electronics             Lenovo   5399     3.2   8269       7%
# 3        E1003  electronics              Apple  28799     3.7   6969       6%
# 4        E1004  electronics               boAt  72899     3.6   5488      13%
# ..         ...          ...                ...    ...     ...    ...      ...
# 145      H5025         home       Asian Paints  15099     3.0   5398       8%
# 146      H5026         home       Asian Paints  21499     4.7   7191      44%
# 147      H5027         home            Havells  22299     3.4   1603      51%
# 148      H5028         home  Bajaj Electricals   5699     4.3   9165      38%
# 149      H5029         home      Philips India  19799     4.3   8297       9%
#
# [150 rows x 7 columns]
