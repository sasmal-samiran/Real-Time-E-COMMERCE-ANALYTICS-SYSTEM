# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from Generators.session_generator import generate_sessions

# %%
sessions = generate_sessions('U1001')

# %%
sessions
# Out:
# [{'timestamp': '2026-03-15T11:09:15.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': None},
#  {'timestamp': '2026-03-15T11:09:29.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'F2015',
#   'category': 'fashion'},
#  {'timestamp': '2026-03-15T11:09:54.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00009',
#   'page': 'wishlist',
#   'event_type': 'add_to_wishlist',
#   'product_id': None,
#   'category': 'fashion'},
#  {'timestamp': '2026-03-15T11:10:01.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'fashion'},
#  {'timestamp': '2026-03-15T11:10:19.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00019',
#   'page': 'login',
#   'event_type': 'login',
#   'product_id': None,
#   'category': 'fashion'},
#  {'timestamp': '2026-03-15T11:10:26.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'fashion'},
#  {'timestamp': '2026-03-15T11:11:08.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00002',
#   'page': 'search',
#   'event_type': 'search',
#   'product_id': None,
#   'category': 'fashion'},
#  {'timestamp': '2026-03-15T11:11:41.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00003',
#   'page': 'category',
#   'event_type': 'browse_category',
#   'product_id': None,
#   'category': 'electronics'},
#  {'timestamp': '2026-03-15T11:12:08.351684',
#   'user_id': 'U1001',
#   'session_id': 'S187148',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'E1011',
#   'category': 'electronics'}]

# %%
len(sessions)
# Out:
# 9

# %%
import pandas as pd

# %%
df = pd.DataFrame(sessions)

# %%
df
# Out:
#                     timestamp user_id session_id event_id      page  \
# 0  2026-03-15T11:09:15.351684   U1001    S187148   E00001      home
# 1  2026-03-15T11:09:29.351684   U1001    S187148   E00005   product
# 2  2026-03-15T11:09:54.351684   U1001    S187148   E00009  wishlist
# 3  2026-03-15T11:10:01.351684   U1001    S187148   E00001      home
# 4  2026-03-15T11:10:19.351684   U1001    S187148   E00019     login
# 5  2026-03-15T11:10:26.351684   U1001    S187148   E00001      home
# 6  2026-03-15T11:11:08.351684   U1001    S187148   E00002    search
# 7  2026-03-15T11:11:41.351684   U1001    S187148   E00003  category
# 8  2026-03-15T11:12:08.351684   U1001    S187148   E00005   product
#
#         event_type product_id     category
# 0        page_view        NaN          NaN
# 1     view_product      F2015      fashion
# 2  add_to_wishlist        NaN      fashion
# 3        page_view        NaN      fashion
# 4            login        NaN      fashion
# 5        page_view        NaN      fashion
# 6           search        NaN      fashion
# 7  browse_category        NaN  electronics
# 8     view_product      E1011  electronics

# %%
sessions = generate_sessions('U1002')

# %%
sessions
# Out:
# [{'timestamp': '2026-03-15T14:50:31.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': None,
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/home',
#   'referrer_url': None,
#   'time_on_page': 10.823304640718398,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:51:11.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00002',
#   'page': 'search',
#   'event_type': 'search',
#   'product_id': None,
#   'category': None,
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/search',
#   'referrer_url': '/home',
#   'time_on_page': 43.77129360766531,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:51:28.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'F2029',
#   'category': 'fashion',
#   'price': 3299,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/product/F2029',
#   'referrer_url': '/search',
#   'time_on_page': 23.86865209794539,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:51:44.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00002',
#   'page': 'search',
#   'event_type': 'search',
#   'product_id': None,
#   'category': 'fashion',
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/search',
#   'referrer_url': '/product/F2029',
#   'time_on_page': 22.88143765540853,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:52:21.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'F2006',
#   'category': 'fashion',
#   'price': 3799,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/product/F2006',
#   'referrer_url': '/search',
#   'time_on_page': 7.338019631323547,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:52:56.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00002',
#   'page': 'search',
#   'event_type': 'search',
#   'product_id': None,
#   'category': 'fashion',
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/search',
#   'referrer_url': '/product/F2006',
#   'time_on_page': 50.95502090557127,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:53:21.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'F2015',
#   'category': 'fashion',
#   'price': 2899,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/product/F2015',
#   'referrer_url': '/search',
#   'time_on_page': 56.72906728798146,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:53:58.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00005',
#   'page': 'product',
#   'event_type': 'view_product',
#   'product_id': 'F2006',
#   'category': 'fashion',
#   'price': 3799,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/product/F2006',
#   'referrer_url': '/product/F2015',
#   'time_on_page': 24.999156083416672,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:54:42.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00009',
#   'page': 'wishlist',
#   'event_type': 'add_to_wishlist',
#   'product_id': None,
#   'category': 'fashion',
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/wishlist',
#   'referrer_url': '/product/F2006',
#   'time_on_page': 30.52572288665864,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:55:07.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00001',
#   'page': 'home',
#   'event_type': 'page_view',
#   'product_id': None,
#   'category': 'fashion',
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/home',
#   'referrer_url': '/wishlist',
#   'time_on_page': 15.725204583800888,
#   'cart_value': None,
#   'is_purchase': False},
#  {'timestamp': '2026-03-15T14:55:38.370883',
#   'user_id': 'U1002',
#   'session_id': 'S436031',
#   'event_id': 'E00002',
#   'page': 'search',
#   'event_type': 'search',
#   'product_id': None,
#   'category': 'fashion',
#   'price': None,
#   'quantity': None,
#   'device_type': 'tablet',
#   'browser': 'safari',
#   'country': 'India',
#   'traffic_source': 'social',
#   'page_url': '/search',
#   'referrer_url': '/home',
#   'time_on_page': 58.83646402865462,
#   'cart_value': None,
#   'is_purchase': False}]

# %%
df = pd.DataFrame(sessions)

# %%
df.columns
# Out:
# Index(['timestamp', 'user_id', 'session_id', 'event_id', 'page', 'event_type',
#        'product_id', 'category', 'price', 'quantity', 'device_type', 'browser',
#        'country', 'traffic_source', 'page_url', 'referrer_url', 'time_on_page',
#        'cart_value', 'is_purchase'],
#       dtype='str')

# %%
dict1 = {
    "Name":"Asim"
}

# %%
dict1['Name']
# Out:
# 'Asim'

# %%
dict1.get("Name")
# Out:
# 'Asim'
