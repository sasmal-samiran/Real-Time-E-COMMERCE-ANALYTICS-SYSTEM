# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Synthetic_Data_Generator.Generators.session_generator import generate_sessions
#
# ModuleNotFoundError: No module named 'Synthetic_Data_Generator'
